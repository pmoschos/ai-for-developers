# %%
import code_gen
from prompts import CODE_GENERATION_PROMPT, TEST_GENERATION_PROMPT
import argparse

# %%
mydict = {"k1": "v1", "k2": "v2"}
mydict["k3"] = "v3"
print(mydict)
# Out:
# {'k1': 'v1', 'k2': 'v2', 'k3': 'v3'}

# %%
parser = argparse.ArgumentParser(description='')
parser.add_argument('description', type=str, help='A description of the code to generate')
parser.add_argument('--with-tests', action='store_true', help='Whether to generate tests for the code')
parser.add_argument('--save', action='store_true', help='Whether to save the generated code to a file')
parser.add_argument('-i', action='store_true', help='Whether to generate code interactively')
args = parser.parse_args()
print(args.with_tests)
# Out:
# usage: ipykernel_launcher.py [-h] [--with-tests] [--save] [-i] description
# ipykernel_launcher.py: error: the following arguments are required: description
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# c:\Users\iason\Documents\EDU\ΟΠΑ\AI for Developes\3. THe Art and Science of Prompt Engineering\labs\venv\Lib\site-packages\IPython\core\interactiveshell.py:3755: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
my_dict = {"k1": "v1", "k2": "v2"}
sm = my_dict.get("k2", "default_value")
print(sm)
# Out:
# v2
